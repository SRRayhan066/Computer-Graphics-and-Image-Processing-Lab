# %%
import matplotlib.pyplot as plt
import math

# %%
x = 2
y = 3

# %%
plt.plot(x, y, 'o', color='blue')
plt.title('Single point printing')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.xlim(0,5)
plt.ylim(0,5)
plt.grid('true')
