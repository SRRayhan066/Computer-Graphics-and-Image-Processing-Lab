# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Translation

# %%
def translation(p):
    tx, ty = 5, 0
    t = np.array([[tx], [ty]])
    r = p + t
    
    return r

# %%
p = np.array([[2, 6], [6, 8]]) # orginal points

r = translation(p)

# %%
print(r)
# Out:
# [[ 7 11]
#  [ 6  8]]

# %%
plt.plot(p[0], p[1], color = 'blue', marker = 'o')
plt.plot(r[0], r[1], color = 'red', marker = 'x')
plt.title("2D-translation")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid("true")
